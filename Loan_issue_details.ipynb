# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox
from PIL import Image,ImageTk

class MyProject:
    
    
    def __init__(self,win):
        
        #p1=PhotoImage(file='D:\\Loan.png')
        #win.iconphoto(False,p1)
        
        frame1=Frame(win,height=750,width=800,bd=5,bg='grey',relief="groove")
        frame1.place(x=0,y=0)
        
        
        lbl=Label(win,text="Loan issue detail ",font=('algerian',25),padx=5,pady=5,borderwidth=5,relief="groove",bg='grey77')
        lbl.place(x=240,y=30)
        

    
        
        frame2=Frame(win,height=400,width=700,bd=5,bg='grey77',relief="groove")
        frame2.place(x=40,y=100)
        
        '''my_pic=Image.open('D:\\Loanissue.gif')
        img=ImageTk.PhotoImage(my_pic)
        label=Label(win,image=img,height=200,width=200)
        label.image=img
        label.place(x=500,y=200)'''
        
        
        lbl1=Label(win,text='Loan Id', font=('Helvetica',14),bg='grey77')
        lbl1.place(x=70,y=120)
        
        entry1=Entry(win,font=('Helvetica',14))
        entry1.place(x=250,y=120)
        
        lbl2=Label(win,text='Issue Date',font=('Helvetica',14),bg='grey77')
        lbl2.place(x=70,y=160)
        
        lbl7=Label(win,text='(yyyy/mm/dd)',font=('Helvetica',10),bg='grey77')
        lbl7.place(x=475,y=160)
        
        entry2=Entry(win,font=('Helvetica',14))
        entry2.place(x=250,y=160)
        
        lbl3=Label(win,text='Loan Duration(Year)',font=('Helvetica',14),bg='grey77')
        lbl3.place(x=70,y=200)
        
        entry3=Entry(win,font=('Helvetica',14))
        entry3.place(x=250,y=200)
        
        lbl4=Label(win,text='EMI',font=('Helvetica',14),bg='grey77')
        lbl4.place(x=70,y=240)
        
        entry4=Entry(win,font=('Helvetica',14))
        entry4.place(x=250,y=240)
        
        lbl5=Label(win,text='Cheque Number',font=('Helvetica',14),bg='grey77')
        lbl5.place(x=70,y=280)
        
        entry5=Entry(win,font=('Helvetica',14))
        entry5.place(x=250,y=280)
        
        lbl6=Label(win,text='Issuing Bank',font=('Helvetica',14),bg='grey77')
        lbl6.place(x=70,y=320)
        
        entry6=Entry(win,font=('Helvetica',14))
        entry6.place(x=250,y=320)
        
        btn1=Button(win,text='first',width=9,font=('algerian',10),padx=5,pady=5,borderwidth=5,relief='groove')
        btn1.place(x=70,y=380)
        
        btn2=Button(win,text='previous',width=9,font=('algerian',10),padx=5,pady=5,borderwidth=5,relief='groove')
        btn2.place(x=180,y=380)
        
        btn3=Button(win,text='next',width=9,font=('algerian',10),padx=5,pady=5,borderwidth=5,relief='groove')
        btn3.place(x=290,y=380)
        
        btn4=Button(win,text='last',width=9,font=('algerian',10),padx=5,pady=5,borderwidth=5,relief='groove')
        btn4.place(x=400,y=380)
        
        btn5=Button(win,text='Add',width=9,font=('algerian',10),padx=5,pady=5,borderwidth=5,relief='groove')
        btn5.place(x=70,y=430)
        
        btn6=Button(win,text='Update',width=9,font=('algerian',10),padx=5,pady=5,borderwidth=5,relief='groove')
        btn6.place(x=180,y=430)
        
        btn7=Button(win,text='Save',width=9,font=('algerian',10),padx=5,pady=5,borderwidth=5,relief='groove')
        btn7.place(x=290,y=430)
        
        btn8=Button(win,text='Cancel',width=9,font=('algerian',10),padx=5,pady=5,borderwidth=5,relief='groove')
        btn8.place(x=400,y=430)

if __name__ ==  '__main__':
    window = Tk()
    MyProject(window)
    window.title('Loan Issue Detail ')
    window.geometry('800x570+400+50')
    window.resizable(0,0)
    window.mainloop()
