# %%
import MySQLdb
from tkinter import *
from tkinter import ttk
import datetime
import time
import tkinter.messagebox
from tkinter.ttk import Combobox


class EmiLoanCalc:
    def __init__(self,win):
        
        p1=PhotoImage(file='Loan.png')
        win.iconphoto(False,p1)
        
        lbl=Label(window,text="Loan File Details",height=1,width=20,bg="lightgrey",fg="black",font=("arial",17,"bold"),borderwidth=5,relief="groove")
        lbl.place(x=170,y=20)
        
        lbl=Label(window,text="Loan Evaluation",height=1,width=20,bg="lightgrey",fg="black",font=("arial",17,"bold"),borderwidth=5,relief="groove")
        lbl.place(x=860,y=20)
        
        # LEFT AND RIGHT FRAMES CREATION
        
        left_frame=Frame(win,height=610,width=650,bd=5,bg='lightgrey',relief="groove")
        left_frame.place(x=20,y=80)
        
        
        right_frame=Frame(win,height=610,width=650,bd=5,bg='lightgrey',relief="groove")
        right_frame.place(x=690,y=80)
        
        
        # LEFT FRAME FORM
        # ENTRY FIELD
        lbl1=Label(win,text="File ID",bg="lightgrey",fg="black",font=("arial",12,"bold"))
        lbl1.place(x=50,y=110)
        entry1=Entry(win,font=('Helvetica',14))
        entry1.place(x=150,y=110)
        
        #LEFT FRAME COMBOBOXES
        lbl2=Label(win,text='Plan',bg="lightgrey",fg="black",font=("arial",12,"bold"))
        lbl2.place(x=50,y=160)
        loan_type=("Home Loan","Car Loan")
        c1=Combobox(win,values=loan_type)
        c1.place(x=150,y=160)
        
        lbl3=Label(win,text="Client",bg="lightgrey",fg="black",font=("arial",12,"bold"))
        lbl3.place(x=50,y=210)
        clients=("Madhu","Ruchi","Anjali","Abhishek","Vishu")
        c2=Combobox(win,values=clients)
        c2.place(x=150,y=210)
        
        #LEFT FRAME CHECK BUTTONS
        lbl4=Label(win,text="ID Proof",bg="lightgrey",fg="black",font=("arial",12,"bold"))
        lbl4.place(x=50,y=260)
        c1=Checkbutton(win,bg="lightgrey")
        c1.place(x=200,y=260)
        
        lbl5=Label(win,text="Residence Proof",bg="lightgrey",fg="black",font=("arial",12,"bold"))
        lbl5.place(x=50,y=310)
        c2=Checkbutton(win,bg="lightgrey")
        c2.place(x=200,y=310)
        
        lbl6=Label(win,text="Income Proof",bg="lightgrey",fg="black",font=("arial",12,"bold"))
        lbl6.place(x=50,y=360)
        c3=Checkbutton(win,bg="lightgrey")
        c3.place(x=200,y=360)
        
        lbl7=Label(win,text="Bank Statement",bg="lightgrey",fg="black",font=("arial",12,"bold"))
        lbl7.place(x=50,y=410)
        c4=Checkbutton(win,bg="lightgrey")
        c4.place(x=200,y=410)
        

        #LEFT FORM REMARKS TEXTAREA
        lbl8=Label(win,text="Remarks",bg="lightgrey",fg="black",font=("arial",12,"bold"))
        lbl8.place(x=50,y=460)
        textarea1=Text(win, height=4, width=27)
        textarea1.place(x=150,y=460)
        
        #LEFT FORM STATUS ENTRY FIELD
        lbl9=Label(win,text="Status",bg="lightgrey",fg="black",font=("arial",12,"bold"))
        lbl9.place(x=50,y=550)
        entry2=Entry(win,font=('Helvetica',14))
        entry2.place(x=150,y=550)
        
        #LEFT_FRAME_BUTTONS
        
        btn1=Button(win,text='First',width=9,font=('algerian',12,"bold"),padx=2,pady=2,borderwidth=4)
        btn1.place(x=100,y=590)
        
        btn2=Button(win,text='Previous',width=9,font=('algerian',12,"bold"),padx=2,pady=2,borderwidth=4)
        btn2.place(x=200,y=590)
        
        btn3=Button(win,text='Next',width=9,font=('algerian',12,"bold"),padx=2,pady=2,borderwidth=4)
        btn3.place(x=300,y=590)
        
        btn4=Button(win,text='Last',width=9,font=('algerian',12,"bold"),padx=2,pady=2,borderwidth=4)
        btn4.place(x=400,y=590)
        
        btn5=Button(win,text='Add',width=9,font=('algerian',12,"bold"),padx=2,pady=2,borderwidth=4)
        btn5.place(x=100,y=630)
        
        btn6=Button(win,text='Update',width=9,font=('algerian',12,"bold"),padx=2,pady=2,borderwidth=4)
        btn6.place(x=200,y=630)
        
        btn7=Button(win,text='Save',width=9,font=('algerian',12,"bold"),padx=2,pady=2,borderwidth=4)
        btn7.place(x=300,y=630)
        
        btn7=Button(win,text='Cancel',width=9,font=('algerian',12,"bold"),padx=2,pady=2,borderwidth=4)
        btn7.place(x=400,y=630)
        
        

        #RIGHT FRAME 
        lbl10=Label(win,text='Loan Amount',bg="lightgrey",fg="black",font=("arial",10,"bold"))
        lbl10.place(x=700,y=110)
        entry3=Entry(win,font=('Helvetica',10))
        entry3.place(x=850,y=110)
    
        lbl11=Label(win,text='Rate of Interest',bg="lightgrey",fg="black",font=("arial",10,"bold"))
        lbl11.place(x=1020,y=110)
        entry4=Entry(win,font=('Helvetica',10))
        entry4.place(x=1180,y=110)
    
        lbl12=Label(win,text='Client Monthly Income',bg="lightgrey",fg="black",font=("arial",10,"bold"))
        lbl12.place(x=700,y=150)
        entry5=Entry(win,font=('Helvetica',10))
        entry5.place(x=850,y=150)
        
        lbl13=Label(win,text='Client Monthly Expenses',bg="lightgrey",fg="black",font=("arial",10,"bold"))
        lbl13.place(x=1020,y=150)
        entry6=Entry(win,font=('Helvetica',10))
        entry6.place(x=1180,y=150)
        
        lbl14=Label(win,text='Number of Years',bg="lightgrey",fg="black",font=("arial",10,"bold"))
        lbl14.place(x=700,y=190)
        entry7=Entry(win,font=('Helvetica',10))
        entry7.place(x=850,y=190)
        
        btn8=Button(win,text='Evaluate',width=8,font=('algerian',10,"bold"),padx=2,pady=2,borderwidth=4)
        btn8.place(x=1100,y=190)
        btn9=Button(win,text='Issue',width=8,font=('algerian',10,"bold"),padx=2,pady=2,borderwidth=4)
        btn9.place(x=1230,y=190)
        
        lbl15=Label(win,text="Loan Evaluation Result :",bg="lightgrey",font=('arial',10,"bold"))
        lbl15.place(x=700,y=300)
        
        
        
if __name__=='__main__':
    window=Tk()
    emi=EmiLoanCalc(window)
    window.geometry("1400x700+0+20")
    window.title("Loan File Details and Evaluation")
    #window.attributes('-fullscreen', True)   
    window.mainloop()

# %%
import os
prinos.getcwd
# Out:
# <function nt.getcwd()>
