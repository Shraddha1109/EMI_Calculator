# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox


class MyClient:
    
    def __init__(self,win):
        self.frame1=Frame(win,height=850,width=800,bd=5,bg='grey47',relief="raised")
        self.frame1.place(x=0,y=0)     
        self.lbl=Label(win,text="Client Responsibility details ",font=('Helvetica',25),padx=6,pady=6,borderwidth=4,relief="raised",bg='grey80')
        self.lbl.place(x=120,y=30)
        
        self.lbl1=Label(win,text='Client Id', font=('Alegrian',16),bg='grey84')
        self.lbl1.place(x=70,y=120)
        
        self.entry1=Entry(win,font=('Algerian',16))
        self.entry1.place(x=250,y=120)
        
        self.lbl2=Label(win,text='Tax Deduction',font=('Alegrian',16),bg='grey84')
        self.lbl2.place(x=70,y=160)
        
        lbl8=Label(win,text='(yearly....)',font=('Helvetica',14))
        lbl8.place(x=550,y=160)
        
        self.entry2=Entry(win,font=('Alegrian',16))
        self.entry2.place(x=250,y=160)
       
        self.lbl3=Label(win,text='Loan EMI',font=('Alegrian',16),bg='grey84')
        self.lbl3.place(x=70,y=200)
        
        lbl9=Label(win,text='(monthly....)',font=('Helvetica',14))
        lbl9.place(x=550,y=200)
        
        self.entry3=Entry(win,font=('Alegrian',16))
        self.entry3.place(x=250,y=200)

        self.lbl4=Label(win,text='Insurance EMI',font=('Alegrian',16),bg='grey84')
        self.lbl4.place(x=70,y=240)

        self.entry4=Entry(win,font=('Alegrian',16))
        self.entry4.place(x=250,y=240)
        
        lbl10=Label(win,text='(monthly....)',font=('Helvetica',14))
        lbl10.place(x=550,y=240)
        
        self.lbl5=Label(win,text='House Rent',font=('Alegrian',16),bg='grey84')
        self.lbl5.place(x=70,y=280)
        
        self.entry5=Entry(win,font=('Alegrian',16))
        self.entry5.place(x=250,y=280)
        
        lbl11=Label(win,text='(monthly....)',font=('Helvetica',14))
        lbl11.place(x=550,y=280)
        
        self.lbl6=Label(win,text='Dependants',font=('Alegrian',16),bg='grey84')
        self.lbl6.place(x=70,y=320)
        
        self.entry6=Entry(win,font=('Alegrian',16))
        self.entry6.place(x=250,y=320)
        
        self.lbl7=Label(win,text='My Expenditure',font=('Alegrian',16),bg='grey84')
        self.lbl7.place(x=70,y=360)
        
        self.entry7=Entry(win,font=('Alegrian',16))
        self.entry7.place(x=250,y=360)
        
        lbl12=Label(win,text='(monthly....)',font=('Helvetica',14))
        lbl12.place(x=550,y=360)
        
        self.lbl7=Label(win,text='Health Expenditure',font=('Alegrian',16),bg='grey84')
        self.lbl7.place(x=70,y=400)
        
        self.entry7=Entry(win,font=('Alegrian',16))
        self.entry7.place(x=250,y=400)
        
        lbl13=Label(win,text='(monthly....)',font=('Helvetica',14))
        lbl13.place(x=550,y=400)
     
        self.btn1=Button(win,text='first',width=9,font=('Times New Roman',12),padx=6,pady=6,borderwidth=4,relief="raised")
        self.btn1.place(x=70,y=460)
        
        self.btn2=Button(win,text='previous',width=9,font=('Times New Roman',12),padx=6,pady=6,borderwidth=4,relief="raised")
        self.btn2.place(x=180,y=460)
        
        self.btn3=Button(win,text='next',width=9,font=('Times New Roman',12),padx=6,pady=6,borderwidth=4,relief="raised")
        self.btn3.place(x=290,y=460)
        
        self.btn4=Button(win,text='last',width=9,font=('Times New Roman',12),padx=6,pady=6,borderwidth=4,relief="raised")
        self.btn4.place(x=400,y=460)
        
        self.btn5=Button(win,text='Add',width=9,font=('Times New Roman',12),padx=6,pady=6,borderwidth=4,relief="raised")
        self.btn5.place(x=70,y=520)
        
        self.btn6=Button(win,text='Update',width=9,font=('Times New Roman',12),padx=6,pady=6,borderwidth=4,relief="raised")
        self.btn6.place(x=180,y=520)
        
        self.btn7=Button(win,text='Save',width=9,font=('Times New Roman',12),padx=6,pady=6,borderwidth=4,relief="raised")
        self.btn7.place(x=290,y=520)
        
        self.btn8=Button(win,text='Cancel',width=9,font=('Times New Roman',12),padx=6,pady=6,borderwidth=4,relief="raised")
        self.btn8.place(x=400,y=520)


window = Tk()
window.title('Client Professional Details')
obj=MyClient(window)
window.geometry('650x650+500+80')
window.resizable(0,0)
window.mainloop()
